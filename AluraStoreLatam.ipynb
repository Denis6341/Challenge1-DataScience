# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

ingresos = {
    "Tienda 1": tienda["Precio"].sum(),
    "Tienda 2": tienda2["Precio"].sum(),
    "Tienda 3": tienda3["Precio"].sum(),
    "Tienda 4": tienda4["Precio"].sum()
}

ingresos
# Out:
# {'Tienda 1': np.float64(1150880400.0),
#  'Tienda 2': np.float64(1116343500.0),
#  'Tienda 3': np.float64(1098019600.0),
#  'Tienda 4': np.float64(1038375700.0)}

# %%
plt.figure()
plt.bar(ingresos.keys(), ingresos.values())
plt.title("Ingreso total por tienda")
plt.xlabel("Tienda")
plt.ylabel("Ingresos")
plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %%
ventas_categoria1 = tienda["Categoría del Producto"].value_counts()
ventas_categoria2 = tienda2["Categoría del Producto"].value_counts()
ventas_categoria3 = tienda3["Categoría del Producto"].value_counts()
ventas_categoria4 = tienda4["Categoría del Producto"].value_counts()

print("Tienda 1")
print(ventas_categoria1)

print("\nTienda 2")
print(ventas_categoria2)

print("\nTienda 3")
print(ventas_categoria3)

print("\nTienda 4")
print(ventas_categoria4)
# Out:
# Tienda 1
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64
#
# Tienda 2
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64
#
# Tienda 3
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64
#
# ...

# %%
plt.figure()
ventas_categoria1.plot(kind="bar")
plt.title("Ventas por categoría - Tienda 1")
plt.xlabel("Categoría")
plt.ylabel("Cantidad vendida")
plt.show()

# %%
plt.figure()
ventas_categoria2.plot(kind="bar")
plt.title("Ventas por categoría - Tienda 2")
plt.xlabel("Categoría")
plt.ylabel("Cantidad vendida")
plt.show()

# %%
plt.figure()
ventas_categoria3.plot(kind="bar")
plt.title("Ventas por categoría - Tienda 3")
plt.xlabel("Categoría")
plt.ylabel("Cantidad vendida")
plt.show()

# %%
plt.figure()
ventas_categoria4.plot(kind="bar")
plt.title("Ventas por categoría - Tienda 4")
plt.xlabel("Categoría")
plt.ylabel("Cantidad vendida")
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
valoraciones = {
    "Tienda 1": tienda["Calificación"].mean(),
    "Tienda 2": tienda2["Calificación"].mean(),
    "Tienda 3": tienda3["Calificación"].mean(),
    "Tienda 4": tienda4["Calificación"].mean()
}

valoraciones
# Out:
# {'Tienda 1': np.float64(3.976685036032217),
#  'Tienda 2': np.float64(4.037303942348453),
#  'Tienda 3': np.float64(4.048325561678677),
#  'Tienda 4': np.float64(3.9957591178965224)}

# %%
plt.figure()
plt.bar(valoraciones.keys(), valoraciones.values())
plt.title("Valoración promedio por tienda")
plt.ylabel("Calificación promedio")
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
ventas_producto1 = tienda["Producto"].value_counts()

mas_vendido1 = ventas_producto1.idxmax()
menos_vendido1 = ventas_producto1.idxmin()

print("Producto más vendido tienda 1:", mas_vendido1)
print("Producto menos vendido tienda 1:", menos_vendido1)

plt.figure()
ventas_producto1.head(10).plot(kind="bar")
plt.title("Top 10 productos más vendidos - Tienda 1")
plt.ylabel("Cantidad vendida")
plt.show()
# Out:
# Producto más vendido tienda 1: Microondas
# Producto menos vendido tienda 1: Auriculares con micrófono

# %%
ventas_producto2 = tienda2["Producto"].value_counts()

mas_vendido2 = ventas_producto2.idxmax()
menos_vendido2 = ventas_producto2.idxmin()

print("Producto más vendido tienda 2:", mas_vendido2)
print("Producto menos vendido tienda 2:", menos_vendido2)

plt.figure()
ventas_producto2.head(10).plot(kind="bar")
plt.title("Top 10 productos más vendidos - Tienda 2")
plt.ylabel("Cantidad vendida")
plt.show()
# Out:
# Producto más vendido tienda 2: Iniciando en programación
# Producto menos vendido tienda 2: Juego de mesa

# %%
ventas_producto3 = tienda3["Producto"].value_counts()

mas_vendido3 = ventas_producto3.idxmax()
menos_vendido3 = ventas_producto3.idxmin()

print("Producto más vendido tienda 3:", mas_vendido3)
print("Producto menos vendido tienda 3:", menos_vendido3)

plt.figure()
ventas_producto3.head(10).plot(kind="bar")
plt.title("Top 10 productos más vendidos - Tienda 3")
plt.ylabel("Cantidad vendida")
plt.show()
# Out:
# Producto más vendido tienda 3: Kit de bancas
# Producto menos vendido tienda 3: Bloques de construcción

# %%
ventas_producto4 = tienda4["Producto"].value_counts()

mas_vendido4 = ventas_producto4.idxmax()
menos_vendido4 = ventas_producto4.idxmin()

print("Producto más vendido tienda 4:", mas_vendido4)
print("Producto menos vendido tienda 4:", menos_vendido4)

plt.figure()
ventas_producto4.head(10).plot(kind="bar")
plt.title("Top 10 productos más vendidos - Tienda 4")
plt.ylabel("Cantidad vendida")
plt.show()
# Out:
# Producto más vendido tienda 4: Cama box
# Producto menos vendido tienda 4: Guitarra eléctrica

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
envio_promedio = {
    "Tienda 1": tienda["Costo de envío"].mean(),
    "Tienda 2": tienda2["Costo de envío"].mean(),
    "Tienda 3": tienda3["Costo de envío"].mean(),
    "Tienda 4": tienda4["Costo de envío"].mean()
}

envio_promedio
# Out:
# {'Tienda 1': np.float64(26018.60958033065),
#  'Tienda 2': np.float64(25216.235693090293),
#  'Tienda 3': np.float64(24805.680373039424),
#  'Tienda 4': np.float64(23459.457167090754)}

# %%
plt.figure()
plt.bar(envio_promedio.keys(), envio_promedio.values())
plt.title("Costo de envío promedio por tienda")
plt.ylabel("Costo promedio")
plt.show()

# %% [markdown]
# # Análisis geográfico

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

tienda["Tienda"] = "Tienda 1"
tienda2["Tienda"] = "Tienda 2"
tienda3["Tienda"] = "Tienda 3"
tienda4["Tienda"] = "Tienda 4"

df = pd.concat([tienda, tienda2, tienda3, tienda4])

# %% [markdown]
# ### Ventas por tienda en el mapa

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(data=df, x="lon", y="lat", hue="Tienda")

plt.title("Distribución geográfica de ventas por tienda")

plt.show()
